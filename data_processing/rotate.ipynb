# %%
from parse_touchpad_data import TouchpadData
import pandas as pd
import numpy as np

from pprint import pprint
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D, HandlerTuple
import matplotlib as mpl
import itertools

from scipy import stats
from scipy import linalg
from scipy import ndimage

from PIL import Image

# %%
original = TouchpadData('dataset/rotate/original')
rotated90 = TouchpadData('dataset/rotate/rotated90')
rotated135 = TouchpadData('dataset/rotate/rotated135')
legal = np.array(TouchpadData('../touchpad_capture/real_data/legal').data)
illegal = np.array(TouchpadData('../touchpad_capture/real_data/illegal').data)

# %%
palm_orig = illegal[50]

palm_shifted = ndimage.shift(palm_orig, np.array([0, 4]))


sns.heatmap(palm_orig, xticklabels=False, yticklabels=False)
plt.figure()
sns.heatmap(palm_shifted, xticklabels=False, yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
rotate_test = original.data[0]
ndimage.interpolation.rotate(rotate_test, angle=40, reshape=False)
shift_test = ndimage.shift(original.data[0], np.array([0, 4]))
# todo, get edges of a 2D array, so I can check if it was moved alright


sns.heatmap(original.data[0], xticklabels=False, yticklabels=False)
plt.figure()
# sns.heatmap(rotate_test, xticklabels=False, yticklabels=False)
# plt.figure()
sns.heatmap(shift_test, xticklabels=False, yticklabels=False)
# Out:
# <AxesSubplot:>
