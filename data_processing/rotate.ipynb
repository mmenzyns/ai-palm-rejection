# %%
from parse_touchpad_data import TouchpadData
import pandas as pd
import numpy as np

from pprint import pprint
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D, HandlerTuple
import matplotlib as mpl
import itertools

from scipy import stats
from scipy import linalg

from PIL import Image

# %%
original = TouchpadData('dataset/rotate/original')
rotated90 = TouchpadData('dataset/rotate/rotated90')
rotated135 = TouchpadData('dataset/rotate/rotated135')

# %%
test = TouchpadData('../touchpad_capture/real_data')

# %%
np.shape(test.data)
# Out:
# (3363, 13, 20)

# %%
means = np.mean(test.data, axis=(1,2))
variances = np.var(test.data, axis=(1,2))

# %%
np.where( (variances > 3.8) & (variances < 3.9) )
# Out:
# (array([86]),)

# %%
np.where((means > 0.15) & (means < 0.18))
# Out:
# (array([1627, 1720, 1890, 1999, 2120, 2123, 2172, 2201]),)

# %%
test.data[2092].mean()
# Out:
# 0.11538461538461539

# %%
sns.heatmap(test.data[86], xticklabels=False, yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
print(np.var(test.data[1627]), np.var(test.data[1720]))
# Out:
# 0.2943639053254437 4.245724852071005

# %%
sns.heatmap(rotated135.data[0], xticklabels=False, yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
img = Image.fromarray(original.data[0]).rotate(45)

# %%
data = np.array(img.getdata()).reshape(13,20)
sns.heatmap(data, xticklabels=False, yticklabels=False)
# Out:
# <AxesSubplot:>
