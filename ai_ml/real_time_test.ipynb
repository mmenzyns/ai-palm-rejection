# %%
# Out:
# Driver:  rmi4_f54
# Card:  Synaptics RMI4 Touch Sensor
# Bus Info:  rmi4:rmi4-00.fn54
# Input:  0 Normalized 16-Bit Image
# Input:  1 Raw 16-Bit Image
# Input:  2 True Baseline
# Input:  3 Full Raw Capacitance
# Input:  4 Full Raw Capacitance RX Offset
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-6fe5c5909a99> in <module>
# ----> 1 fd, bufinfo, buffer, buftype = init_stream()
#       2 image = get_image(fd, bufinfo, buffer)
#       3 image = get_image(fd, bufinfo, buffer)
#       4 image = get_image(fd, bufinfo, buffer)
#       5 image = get_image(fd, bufinfo, buffer)
#
# <ipython-input-1-2476493bfd72> in init_stream(path)
#      36     bufrequest.count = 1
#      37
# ---> 38     if ioctl(fd, v4l2.VIDIOC_REQBUFS, bufrequest) < 0:
#      39         raise BufferError("Couldn't request a buffer")
#      40
#
# OSError: [Errno 16] Device or resource busy

# %%
image = image.reshape(13, 20)

# %%
sns.heatmap(image)
# Out:
# <AxesSubplot:>

# %%
legal = np.concatenate((read_grayscale_pngs(
    "out/legal/orig"), read_grayscale_pngs("out/legal/mirrored")))
illegal = np.concatenate((read_grayscale_pngs(
    "out/illegal/orig"), read_grayscale_pngs("out/illegal/mirrored")))

legal_test = read_grayscale_pngs("testing_recurrent/legal")
illegal_test = read_grayscale_pngs("testing_recurrent/illegal")

features = ([], [])

for data in (legal, illegal):
    for image in data:
        features[0].append(marginal.mean(image, dim='x', meanNN_TF=False))
        features[1].append(marginal.std(image, dim='x', meanNN_TF=True))
